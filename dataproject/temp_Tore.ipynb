# %%
# %pip install wbgapi

import wbgapi as wb  #API for world bank

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#List of countries and their ID
print(wb.economy.info())
#List of datavalues and their ID
print(wb.series.info())
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...

# %%
countries = ['USA','DNK','NOR','GBR','DEU','FRA']
series = ['VC.IHR.PSRC.P5','AG.LND.FRST.ZS']
wb.data.DataFrame(series,countries,range(2000,2020),index='time',labels=True).plot(figsize=(20,20))
plt.show()
